# %%
import pandas as pd
import numpy as np
from faker import Faker

fake = Faker()

# Define product names for each category
product_names = {
    'Electronics': ['Smartphone', 'Laptop', 'Tablet', 'Headphones', 'Camera'],
    'Clothing': ['T-shirt', 'Jeans', 'Jacket', 'Dress', 'Sneakers'],
    'Grocery': ['Milk', 'Bread', 'Eggs', 'Fruits', 'Vegetables'],
    'Furniture': ['Chair', 'Table', 'Sofa', 'Bed', 'Bookshelf'],
    'Sports': ['Football', 'Basketball', 'Tennis Racket', 'Golf Club', 'Yoga Mat'],
    'Books': ['Novel', 'Biography', 'Comics', 'Cookbook', 'Textbook']
}

# Define a list of specific domain names
ecommerce_domains = ['Amazon', 'Flipkart', 'Myntra', 'eBay', 'Meesho']

# Define a list of specific countries
countries = ['United States', 'India', 'Germany', 'Australia', 'Canada', 'Brazil']

def generate_data(num_records, rogue_probability=0.2):  # Increased rogue probability
    data = []
    for _ in range(num_records):
        # Select a random product category
        product_category = fake.random_element(elements=list(product_names.keys()))
        
        # Select a random product name from the chosen category
        product_name = fake.random_element(elements=product_names[product_category])
        
        # Determine payment success or failure
        payment_success = fake.random_element(elements=('Y', 'N'))
        
        # Create a standard record
        record = {
            'order_id': fake.uuid4(),
            'customer_id': fake.uuid4(),
            'customer_name': fake.name(),
            'product_id': fake.uuid4(),
            'product_name': product_name,
            'product_category': product_category,
            'payment_type': fake.random_element(elements=('card', 'Internet Banking', 'UPI', 'Wallet')),
            'qty': np.random.randint(1, 10),
            'price': round(np.random.uniform(10, 500), 2),
            'datetime': fake.date_time_this_decade(),
            'country': fake.random_element(elements=countries),  # Choose from specific countries
            'city': fake.city(),
            'ecommerce_website_name': fake.random_element(elements=ecommerce_domains),
            'payment_txn_id': fake.uuid4(),
            'payment_txn_success': payment_success,
            'failure_reason': fake.sentence() if payment_success == 'N' else None
        }
        
        # Introduce rogue records based on the probability
        if np.random.rand() < rogue_probability:
            # Apply multiple rogue changes to the record
            rogue_fields = fake.random_choices(elements=['qty', 'price', 'payment_type', 'country'], length=2)
            
            if 'qty' in rogue_fields:
                record['qty'] = np.random.choice([-1, 0, 1000])  # Invalid quantities
            if 'price' in rogue_fields:
                record['price'] = np.random.choice([-100, 0])  # Invalid prices
            if 'payment_type' in rogue_fields:
                record['payment_type'] = 'Unknown'  # Invalid payment type
            if 'country' in rogue_fields:
                record['country'] = 'Unknown'  # Invalid country
        
        data.append(record)
    
    return pd.DataFrame(data)

# Generate the data and save it to a CSV file
df = generate_data(10000)
df.to_csv('generated_data2.csv', index=False)

# %% [markdown]
# ##Loading the Data

# %%
import pandas as pd

# Specify the file path
file_path = 'generated_data2.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
df.head()
# Out:
#                                order_id                           customer_id  \
# 0  47d19aff-d177-48f5-a6a2-31a7bac2bfaf  9d4158ba-aec0-4578-b150-992c08bc8475
# 1  046b21f0-dcde-458c-96be-a5111dbf496e  64739806-004e-4622-b2af-3028f64fd7db
# 2  9eaecca6-97ed-4e5c-bb97-11e4ccfa54c4  99ff13f7-259e-48d0-9daf-f49ded3a1a15
# 3  c9e4143b-6177-4a0d-8232-e48e9285d786  a8ff2da2-30ef-46aa-ba62-9c573e8f6ba1
# 4  50aabe84-18e4-4d03-bc22-6a10a435da3b  8283422c-b5f6-4478-90df-68f98c0f3b7a
#
#       customer_name                            product_id product_name  \
# 0      Jamie Porter  134adff7-3fbe-41cb-b416-2d9014a82012   Headphones
# 1     Ricardo Lynch  2db443d1-d1ce-487e-820a-8296b90bb529        Novel
# 2  Christopher Ryan  06273416-cb84-4b29-8481-b24ce06f529f         Eggs
# 3       Mark Hudson  0950112c-0743-4d4f-bfaa-33051f282246       Jacket
# 4     Amanda Nguyen  015d49eb-65f3-4e01-9ec2-dadd3a2f6f09    Golf Club
#
#   product_category      payment_type  qty   price             datetime  \
# 0      Electronics              card    9  319.01  2022-06-07 08:29:17
# 1            Books           Unknown    1  204.86  2020-08-26 14:21:38
# 2          Grocery            Wallet    9   30.41  2021-08-16 22:02:48
# 3         Clothing  Internet Banking    9  173.50  2020-07-31 23:31:29
# 4           Sports            Wallet    5  406.38  2024-08-01 23:02:10
#
#          country               city ecommerce_website_name  \
# 0         Canada            Reidton                 Myntra
# 1        Unknown      Johnstonshire                 Myntra
# 2  United States     Catherinemouth                 Meesho
# 3         Brazil  New Gwendolynfurt                 Meesho
# 4         Canada       East Francis                   eBay
#
#                          payment_txn_id payment_txn_success  \
# 0  4a05484f-958f-4697-854d-56d8bbfabae5                   Y
# 1  ef033396-47a1-4d0e-b889-52ee6481da05                   Y
# 2  0b021a04-c89f-44f6-94f7-81c907b9f6a7                   N
# 3  70690ea2-2a2c-4c5b-be8b-ba2e7ac1d0ae                   Y
# 4  59a109e0-75a3-421c-9f27-375b966ec57a                   Y
#
#                             failure_reason
# 0                                      NaN
# 1                                      NaN
# 2  Available sound follow budget property.
# 3                                      NaN
# 4                                      NaN

# %% [markdown]
# Data Exploration

# %% [markdown]
# Summary of the DataFrame:

# %%
df.info()
#This provides a concise summary, including the number of non-null entries in each column.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                10000 non-null  object
#  1   customer_id             10000 non-null  object
#  2   customer_name           10000 non-null  object
#  3   product_id              10000 non-null  object
#  4   product_name            10000 non-null  object
#  5   product_category        10000 non-null  object
#  6   payment_type            10000 non-null  object
#  7   qty                     10000 non-null  int64
#  8   price                   10000 non-null  float64
#  9   datetime                10000 non-null  object
#  10  country                 10000 non-null  object
#  11  city                    10000 non-null  object
#  12  ecommerce_website_name  10000 non-null  object
#  13  payment_txn_id          10000 non-null  object
#  14  payment_txn_success     10000 non-null  object
#  15  failure_reason          4922 non-null   object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 1.2+ MB

# %% [markdown]
# Checking for Missing Values:

# %%
df.isnull().sum()
#This reveals the total number of missing values per column
# Out:
# order_id                     0
# customer_id                  0
# customer_name                0
# product_id                   0
# product_name                 0
# product_category             0
# payment_type                 0
# qty                          0
# price                        0
# datetime                     0
# country                      0
# city                         0
# ecommerce_website_name       0
# payment_txn_id               0
# payment_txn_success          0
# failure_reason            5078
# dtype: int64

# %% [markdown]
# Unique Values Exploration

# %%
df.nunique()
#This shows the number of unique values per column.
# Out:
# order_id                  10000
# customer_id               10000
# customer_name              9411
# product_id                10000
# product_name                 30
# product_category              6
# payment_type                  5
# qty                          12
# price                      8360
# datetime                   9997
# country                       7
# city                       7743
# ecommerce_website_name        5
# payment_txn_id            10000
# payment_txn_success           2
# failure_reason             4922
# dtype: int64

# %% [markdown]
#  Detecting Rogue Values

# %%
#Identifying Rogue Quantities:
df[df['qty'] <= 0]
# Out:
#                                   order_id  \
# 17    8ed2fe41-fafc-4f7f-b452-074a729c8b5a
# 24    ec4143f6-7534-4703-99ab-5705ee1a0325
# 30    c0308036-2701-4173-9703-5f2bdd80b19a
# 34    33e93921-2241-4c96-9577-99880e7fdde1
# 45    91f04e47-ab80-44f3-805e-e873cde57bbf
# ...                                    ...
# 9933  f57e6d48-dc6b-4a5e-bc32-ef874b0bfabd
# 9951  cfa37976-3cc4-4637-8e47-5417d4d4983b
# 9961  362c82ca-bba1-4aea-af24-0380f96256c7
# 9967  19cf5229-4f01-4db1-bcfd-8ca66d747028
# 9992  48557629-7b42-4b16-8e44-8f864bd6def2
#
#                                customer_id     customer_name  \
# 17    4c454af3-02ec-464d-a1fc-aee9f2798e17      Audrey Reyes
# 24    fa1e8030-a821-4032-bee7-723b145781f8        Pam Curtis
# 30    4df599c5-a2a2-4cd3-a495-8b4585b6aff0   Courtney Zamora
# 34    1d2400aa-3c0f-4ac0-9b14-9f7b4a3ebb2c   Anthony Santana
# 45    de514fce-4d43-4752-8191-4606aaccb197  Diana Mclaughlin
# ...                                    ...               ...
# 9933  fc01bf22-6cc2-4962-b6a0-597ee10ce618    Lauren Sherman
# 9951  2c91a567-0227-4a53-acc5-c83adcbf4456    Grant Williams
# 9961  92be2e12-1ba5-4630-b7ff-f9cd2b1c2205      Jesse Abbott
# 9967  afb85826-af42-4e2e-9411-7d08112153f9      Nancy Juarez
# 9992  3f2dc3a8-f64c-40d8-979c-6802b8a5f8d8    Jared Mcdonald
#
#                                 product_id product_name product_category  \
# 17    3a50081c-675b-4db3-8bd5-86e0db2128b3   Smartphone      Electronics
# 24    8903e738-9d8b-41eb-b0a0-d3890bd3533c        Jeans         Clothing
# 30    fa8ea7e6-c50f-4e07-8383-03bf806db841    Golf Club           Sports
# 34    852e2b4d-f4c3-4334-8d6b-c6db67715117     Cookbook            Books
# 45    5e9ebf06-ea9e-4d3e-a84a-8092f2e66af0       Tablet      Electronics
# ...                                    ...          ...              ...
# 9933  66bd84e0-d1eb-427f-b208-e3d3ea59c147   Smartphone      Electronics
# 9951  438c0fb7-80bd-4804-a6ba-8605a1505d18       Camera      Electronics
# 9961  1cd7ce8b-5205-463e-b92d-97c367d8984e    Biography            Books
# 9967  1c814b71-9bc6-46c9-bc90-5cb463a0834b   Smartphone      Electronics
# 9992  3fe5e305-a7b2-4b42-be0f-ace44f31609e    Biography            Books
#
#           payment_type  qty   price             datetime        country  \
# 17              Wallet    0 -100.00  2023-10-11 01:36:34         Canada
# 24                card    0    0.00  2023-03-19 00:16:52  United States
# 30              Wallet   -1    0.00  2020-07-19 22:09:23        Germany
# 34                 UPI   -1  132.69  2021-09-17 23:31:41         Brazil
# 45              Wallet   -1    0.00  2021-10-18 10:54:49        Germany
# ...                ...  ...     ...                  ...            ...
# 9933  Internet Banking   -1  133.98  2022-11-22 13:23:17         Brazil
# 9951           Unknown   -1  274.14  2024-05-26 14:40:57      Australia
# 9961               UPI   -1  406.34  2021-12-22 05:01:38          India
# 9967               UPI    0  108.25  2023-12-14 22:58:18        Unknown
# 9992              card    0  178.37  2022-12-17 17:57:52        Unknown
#
#                   city ecommerce_website_name  \
# 17           Silvafurt                 Meesho
# 24         New Michael                 Meesho
# 30    New Rebeccaville                 Amazon
# 34       Lake Michelle               Flipkart
# 45       Kelleychester               Flipkart
# ...                ...                    ...
# 9933     Thompsonhaven                 Amazon
# 9951    North Jennifer                 Myntra
# 9961   Port Samuelland               Flipkart
# 9967       Allisonfort                   eBay
# 9992  New Christinaton               Flipkart
#
#                             payment_txn_id payment_txn_success  \
# 17    b1aabdbe-4ce6-4a65-9fb0-4e2431585713                   N
# 24    e76432bb-9081-45fc-b554-1635ac16ba39                   N
# 30    5a50947d-f41c-4b2f-aa42-eb97a14e5e97                   N
# 34    29c0d38f-ee22-4c24-9be7-4653ac01c0d5                   N
# 45    e3bf7288-be11-4d88-8af6-b34b844eedc9                   N
# ...                                    ...                 ...
# 9933  d4990630-d3f6-4383-8668-8b82123be6e9                   Y
# 9951  658eab0b-19f9-4f0f-b28e-5f3aee3efe41                   Y
# 9961  ab5c4eaa-35bc-4993-8040-9922e22657e8                   N
# 9967  5964634b-ea62-4760-8a09-d67ab83a2725                   Y
# 9992  537fdd30-3cb8-4a2b-85bb-4b0e88c963b1                   N
#
#                                   failure_reason
# 17                           Speech open set or.
# 24             Economy indicate always box case.
# 30        Good down arm region pull myself very.
# 34                Impact answer specific travel.
# 45    Leg them east behind firm appear daughter.
# ...                                          ...
# 9933                                         NaN
# 9951                                         NaN
# 9961             He may government lay response.
# 9967                                         NaN
# 9992        Same assume feel past those medical.
#
# [532 rows x 16 columns]

# %%
#Identifying Rogue Quantities:
df[df['qty'] > 100]
#This helps in spotting records where the quantity is either negative, zero, or unusually high.
# Out:
#                                   order_id  \
# 14    db095c2c-e843-4484-9070-181bd4e652aa
# 26    bd239649-72e5-4e60-9d46-f55438d67ae6
# 50    f4ef5ab8-0081-4fb5-9bd1-a08ab12bdc90
# 132   5874874b-dccf-4587-b388-ea758d9cf2f5
# 138   b3d7a3c6-c2a1-4db8-98a0-e274cc8230d0
# ...                                    ...
# 9719  7e86ef6f-9f7b-4888-aa02-1961b63d8cc9
# 9723  c1dad6fb-030b-4977-a2dd-006264f0c1de
# 9732  3b9f9125-ddd6-49f2-87be-3be267d786bd
# 9779  4f3f98f1-518e-476e-9e06-438985dd22e7
# 9856  53c33a78-8621-4a34-a0de-7ad094dcc619
#
#                                customer_id     customer_name  \
# 14    3794120b-6015-4245-ab32-867f2d168d88       Julia Lopez
# 26    4afb968f-00a9-412f-bf86-30972eb69e7c        Cathy Paul
# 50    0068dc1c-f1a2-4951-91b6-fae817a33cbf     Yvette Walker
# 132   0a4a5cab-897b-48e8-9c7a-f3cde63fa55a      Wanda Romero
# 138   f406ce54-9357-467c-a23a-04bfdd524bd5      Tammy Carter
# ...                                    ...               ...
# 9719  8b7a46c4-8a07-434c-81b4-f41325499a70    Nicole Collins
# 9723  c8953e96-29af-44c4-a0dc-8e16531f0627   Matthew Bernard
# 9732  6a76ccca-56f2-4b46-92d5-b4ceb932d04c     Kevin Griffin
# 9779  af738412-b981-4ac6-a6fb-5096bb9e680a  Michael Thompson
# 9856  f634555f-e408-4c5d-b8c1-5d5732962acd     Emily Osborne
#
#                                 product_id product_name product_category  \
# 14    d4ed8988-64ef-4a83-8bd6-9fdc4130c9e4        Chair        Furniture
# 26    6ba0053a-fd62-4377-a794-776a756a3ca0       Comics            Books
# 50    dfbafe01-03d1-46bf-9092-3c8f846566f3    Golf Club           Sports
# 132   10b47865-1072-4ca5-985e-d2fb04356d99        Chair        Furniture
# 138   49fe4e2a-3697-4839-90ea-784d22f13f3e        Dress         Clothing
# ...                                    ...          ...              ...
# 9719  63b6ca35-eff6-486b-8992-2c056edac67e          Bed        Furniture
# 9723  b81d90d8-abda-400a-9759-d91ffaeb116f       Fruits          Grocery
# 9732  4eadced0-8d3f-4510-b5b3-5b09ab0af762       Fruits          Grocery
# 9779  7e5f380c-8623-4a0c-8f7c-ea4897ce271b   Smartphone      Electronics
# 9856  08a08a79-3e7f-4708-aa90-5497d27b7e28   Basketball           Sports
#
#           payment_type   qty   price             datetime        country  \
# 14                card  1000  453.37  2024-08-10 16:42:42        Unknown
# 26                 UPI  1000 -100.00  2020-07-23 14:28:53  United States
# 50              Wallet  1000  416.93  2020-02-25 03:25:45        Unknown
# 132            Unknown  1000  263.88  2021-04-16 23:00:08  United States
# 138               card  1000  457.50  2024-03-14 08:06:39        Unknown
# ...                ...   ...     ...                  ...            ...
# 9719  Internet Banking  1000    0.00  2023-06-27 19:27:16      Australia
# 9723           Unknown  1000  284.55  2022-06-18 11:55:46  United States
# 9732              card  1000    0.00  2023-05-18 20:20:35         Brazil
# 9779           Unknown  1000  342.37  2021-06-29 00:19:51         Brazil
# 9856               UPI  1000 -100.00  2024-06-04 11:45:25  United States
#
#                   city ecommerce_website_name  \
# 14            Boydland                 Myntra
# 26       Lake Jennifer                 Myntra
# 50        Sanchezburgh                 Amazon
# 132         Hamptonton                 Amazon
# 138   New Jessicaville                 Amazon
# ...                ...                    ...
# 9719         Diazville                   eBay
# 9723   New Codyborough               Flipkart
# 9732         Johnmouth                   eBay
# 9779       Yeseniaview                 Amazon
# 9856     Elizabethstad                 Amazon
#
#                             payment_txn_id payment_txn_success  \
# 14    83c956fe-3b47-4007-bf25-779ec9efb5f1                   Y
# 26    78886eb5-cdb4-45ad-bdb5-aa7c385eb06a                   Y
# 50    9aa6cdf8-acfe-4386-85c9-39f5486faeec                   Y
# 132   c84827e4-8354-4a3e-91b8-cfcf3bb587ea                   N
# 138   87e6a1c4-9cd4-4aec-8b43-ec911d0eb2de                   Y
# ...                                    ...                 ...
# 9719  4f119a3f-2475-45f8-aebd-b52f7bec47dd                   N
# 9723  d4594581-22c4-4e78-be7b-f436e53fd677                   Y
# 9732  e022477a-d118-45cd-a502-7a11f92f6a23                   Y
# 9779  acfd7e06-c80c-4dcb-91e6-77640f0d31f5                   N
# 9856  7d7f27f8-a1e2-40fb-88ad-0905bb3736a9                   Y
#
#                                        failure_reason
# 14                                                NaN
# 26                                                NaN
# 50                                                NaN
# 132   View program effort argue require should range.
# 138                                               NaN
# ...                                               ...
# 9719         Necessary he million outside adult tend.
# 9723                                              NaN
# 9732                                              NaN
# 9779                       Case authority name color.
# 9856                                              NaN
#
# [299 rows x 16 columns]

# %% [markdown]
# Identifying Rogue Prices

# %%
df[df['price'] <= 0]
#This finds records where the price is either zero or negative.
# Out:
#                                   order_id  \
# 17    8ed2fe41-fafc-4f7f-b452-074a729c8b5a
# 24    ec4143f6-7534-4703-99ab-5705ee1a0325
# 26    bd239649-72e5-4e60-9d46-f55438d67ae6
# 30    c0308036-2701-4173-9703-5f2bdd80b19a
# 35    3bcc5fdb-0699-4453-a71e-81e081e033df
# ...                                    ...
# 9874  647abc50-0aa9-43c9-b6f8-2e28c18158df
# 9914  a24df978-3ae6-4eac-a079-d14f412e6ff6
# 9924  f8b14f37-4e89-4264-98d8-a216ef04daea
# 9947  151935af-07f4-44d7-9957-22f5534ec531
# 9985  dcc455b4-f41e-45a6-8c4d-5fc48883c7d1
#
#                                customer_id    customer_name  \
# 17    4c454af3-02ec-464d-a1fc-aee9f2798e17     Audrey Reyes
# 24    fa1e8030-a821-4032-bee7-723b145781f8       Pam Curtis
# 26    4afb968f-00a9-412f-bf86-30972eb69e7c       Cathy Paul
# 30    4df599c5-a2a2-4cd3-a495-8b4585b6aff0  Courtney Zamora
# 35    cc363b21-16a7-4ff7-8f85-11a5d5d566ce      Sherry York
# ...                                    ...              ...
# 9874  9df0764f-7969-488d-821c-b3de56266dfc    Michael Green
# 9914  db0143d0-6152-47fc-87b0-01b13d248067     Diane Tucker
# 9924  28d1d6bf-4af1-4ab8-9e09-a53aed1d8a85    Joshua Norman
# 9947  802658bc-b013-49ce-8440-c78eb5387792     Daniel Jones
# 9985  87cf3559-da54-41b9-85c5-e35e8f42b301  Gavin Robertson
#
#                                 product_id product_name product_category  \
# 17    3a50081c-675b-4db3-8bd5-86e0db2128b3   Smartphone      Electronics
# 24    8903e738-9d8b-41eb-b0a0-d3890bd3533c        Jeans         Clothing
# 26    6ba0053a-fd62-4377-a794-776a756a3ca0       Comics            Books
# 30    fa8ea7e6-c50f-4e07-8383-03bf806db841    Golf Club           Sports
# 35    5b586338-4032-4213-8958-f88182b37542     Textbook            Books
# ...                                    ...          ...              ...
# 9874  de92479a-da8d-407e-8062-7a68168e7bdf   Headphones      Electronics
# 9914  bf93d09e-3647-4671-a9f1-d4f8f7564011       Tablet      Electronics
# 9924  073fc1d7-41d7-4ae6-bbe8-ce2516fc5aad      T-shirt         Clothing
# 9947  b48d5d2b-6076-4d05-aef6-109c53f4180c     Cookbook            Books
# 9985  c02b8e02-11c3-4f0d-8d22-e7e64888c677        Jeans         Clothing
#
#           payment_type   qty  price             datetime        country  \
# 17              Wallet     0 -100.0  2023-10-11 01:36:34         Canada
# 24                card     0    0.0  2023-03-19 00:16:52  United States
# 26                 UPI  1000 -100.0  2020-07-23 14:28:53  United States
# 30              Wallet    -1    0.0  2020-07-19 22:09:23        Germany
# 35             Unknown     7    0.0  2023-10-20 16:15:30      Australia
# ...                ...   ...    ...                  ...            ...
# 9874              card     0 -100.0  2022-05-04 18:24:49         Canada
# 9914           Unknown     8 -100.0  2023-02-09 23:56:06      Australia
# 9924  Internet Banking     2 -100.0  2020-12-16 18:51:35        Unknown
# 9947              card     5    0.0  2022-03-25 17:43:29        Unknown
# 9985           Unknown     7 -100.0  2020-04-29 19:35:56         Canada
#
#                     city ecommerce_website_name  \
# 17             Silvafurt                 Meesho
# 24           New Michael                 Meesho
# 26         Lake Jennifer                 Myntra
# 30      New Rebeccaville                 Amazon
# 35    Port Jenniferhaven               Flipkart
# ...                  ...                    ...
# 9874       West Markport                 Myntra
# 9914    South Lesliefurt                 Myntra
# 9924   East Gabrielabury                   eBay
# 9947          Jorgehaven                 Meesho
# 9985          New Daniel                   eBay
#
#                             payment_txn_id payment_txn_success  \
# 17    b1aabdbe-4ce6-4a65-9fb0-4e2431585713                   N
# 24    e76432bb-9081-45fc-b554-1635ac16ba39                   N
# 26    78886eb5-cdb4-45ad-bdb5-aa7c385eb06a                   Y
# 30    5a50947d-f41c-4b2f-aa42-eb97a14e5e97                   N
# 35    03ebf632-a44a-49ee-b790-9ded05e2e4ea                   N
# ...                                    ...                 ...
# 9874  104c7ed8-127c-4cae-a6cf-3119dca1bb7d                   Y
# 9914  6eac1638-bce9-4119-8b95-35bdae26aacd                   Y
# 9924  80654902-7518-42b0-8f83-520c82f89cec                   N
# 9947  b3fb31a9-c624-4297-aeba-0d88dc907f44                   N
# 9985  d3dc4b5f-875c-4d6f-b62e-dfd9eb244244                   Y
#
#                                        failure_reason
# 17                                Speech open set or.
# 24                  Economy indicate always box case.
# 26                                                NaN
# 30             Good down arm region pull myself very.
# 35        Leader concern step card idea world spring.
# ...                                               ...
# 9874                                              NaN
# 9914                                              NaN
# 9924  Put could seat beautiful protect test standard.
# 9947                    Price apply very skill trial.
# 9985                                              NaN
#
# [874 rows x 16 columns]

# %% [markdown]
# Invalid Payment Types

# %%
df[df['payment_type'] == 'Unknown']
# Out:
#                                   order_id  \
# 1     046b21f0-dcde-458c-96be-a5111dbf496e
# 35    3bcc5fdb-0699-4453-a71e-81e081e033df
# 49    a2fce454-a1b3-445a-a6ec-04829fe7b8a6
# 52    b46cfb6f-cce1-4abb-ab94-b575122763f9
# 86    729f69e6-4b32-499e-88b3-df409741cf94
# ...                                    ...
# 9908  1738af9f-ed6d-4d17-b28a-4661457ebdbc
# 9914  a24df978-3ae6-4eac-a079-d14f412e6ff6
# 9951  cfa37976-3cc4-4637-8e47-5417d4d4983b
# 9985  dcc455b4-f41e-45a6-8c4d-5fc48883c7d1
# 9990  06551b9e-3646-4d02-a728-1d606011d955
#
#                                customer_id         customer_name  \
# 1     64739806-004e-4622-b2af-3028f64fd7db         Ricardo Lynch
# 35    cc363b21-16a7-4ff7-8f85-11a5d5d566ce           Sherry York
# 49    8c5891cd-7d09-414c-a015-3f8df933eb73            Mark Craig
# 52    08abc92f-9c16-4e00-afd0-cea29467959a      Samantha Jackson
# 86    6059a1bb-43ad-4d26-a3b9-4bfd9ce988ee             Aaron Ray
# ...                                    ...                   ...
# 9908  4c9d649d-b180-473d-9bdd-51902ca55eca  Melissa Wilkerson MD
# 9914  db0143d0-6152-47fc-87b0-01b13d248067          Diane Tucker
# 9951  2c91a567-0227-4a53-acc5-c83adcbf4456        Grant Williams
# 9985  87cf3559-da54-41b9-85c5-e35e8f42b301       Gavin Robertson
# 9990  0a7f7562-436b-4a77-b0a7-25b3c4ad109d         Sarah Hampton
#
#                                 product_id product_name product_category  \
# 1     2db443d1-d1ce-487e-820a-8296b90bb529        Novel            Books
# 35    5b586338-4032-4213-8958-f88182b37542     Textbook            Books
# 49    a9bbe267-8883-4919-b5e3-a82c22ff0f89        Novel            Books
# 52    c932f5c7-eb85-4871-995d-d7d371a91afa        Novel            Books
# 86    33a421ea-c079-455c-a47a-9acccd0dcb4d       Jacket         Clothing
# ...                                    ...          ...              ...
# 9908  557eb47f-6fde-4472-af55-16228725ae9a        Novel            Books
# 9914  bf93d09e-3647-4671-a9f1-d4f8f7564011       Tablet      Electronics
# 9951  438c0fb7-80bd-4804-a6ba-8605a1505d18       Camera      Electronics
# 9985  c02b8e02-11c3-4f0d-8d22-e7e64888c677        Jeans         Clothing
# 9990  c4070b73-3f78-4af5-b226-d178132fa4e5      T-shirt         Clothing
#
#      payment_type  qty   price             datetime    country  \
# 1         Unknown    1  204.86  2020-08-26 14:21:38    Unknown
# 35        Unknown    7    0.00  2023-10-20 16:15:30  Australia
# 49        Unknown    6  154.28  2023-07-06 15:35:43    Unknown
# 52        Unknown    1  487.50  2023-05-09 05:41:54    Unknown
# 86        Unknown   -1   50.90  2021-09-23 06:09:27     Brazil
# ...           ...  ...     ...                  ...        ...
# 9908      Unknown    5  446.88  2021-05-02 14:15:03    Unknown
# 9914      Unknown    8 -100.00  2023-02-09 23:56:06  Australia
# 9951      Unknown   -1  274.14  2024-05-26 14:40:57  Australia
# 9985      Unknown    7 -100.00  2020-04-29 19:35:56     Canada
# 9990      Unknown    4  127.51  2023-02-17 23:01:18      India
#
#                     city ecommerce_website_name  \
# 1          Johnstonshire                 Myntra
# 35    Port Jenniferhaven               Flipkart
# 49           Xaviershire                 Myntra
# 52         East Ianmouth                 Myntra
# 86            Thomasstad                 Meesho
# ...                  ...                    ...
# 9908          Joshuaberg                 Myntra
# 9914    South Lesliefurt                 Myntra
# 9951      North Jennifer                 Myntra
# 9985          New Daniel                   eBay
# 9990   North Josephburgh                   eBay
#
#                             payment_txn_id payment_txn_success  \
# 1     ef033396-47a1-4d0e-b889-52ee6481da05                   Y
# 35    03ebf632-a44a-49ee-b790-9ded05e2e4ea                   N
# 49    f82263d9-22a7-4539-8cc8-8361ea021ae3                   Y
# 52    09b5cf1f-56cf-46fc-9703-347fe90aab92                   N
# 86    f3a50aee-8e23-4549-9f9f-349ae40c77d9                   N
# ...                                    ...                 ...
# 9908  279e9c14-04f5-4844-b844-791ba94007a8                   N
# 9914  6eac1638-bce9-4119-8b95-35bdae26aacd                   Y
# 9951  658eab0b-19f9-4f0f-b28e-5f3aee3efe41                   Y
# 9985  d3dc4b5f-875c-4d6f-b62e-dfd9eb244244                   Y
# 9990  304b957c-07ac-4307-9372-f9fd4b32edc8                   N
#
#                                         failure_reason
# 1                                                  NaN
# 35         Leader concern step card idea world spring.
# 49                                                 NaN
# 52                             Month nation both cell.
# 86                         Worker benefit writer that.
# ...                                                ...
# 9908  These wrong despite tonight standard lead leave.
# 9914                                               NaN
# 9951                                               NaN
# 9985                                               NaN
# 9990                                   Suggest so cut.
#
# [931 rows x 16 columns]

# %% [markdown]
# Invalid  Countries:

# %%
df[df['country'] == 'Unknown']
# Out:
#                                   order_id  \
# 1     046b21f0-dcde-458c-96be-a5111dbf496e
# 14    db095c2c-e843-4484-9070-181bd4e652aa
# 49    a2fce454-a1b3-445a-a6ec-04829fe7b8a6
# 50    f4ef5ab8-0081-4fb5-9bd1-a08ab12bdc90
# 52    b46cfb6f-cce1-4abb-ab94-b575122763f9
# ...                                    ...
# 9923  3241e62b-7067-4b1c-9dfb-f6a5286c1dc6
# 9924  f8b14f37-4e89-4264-98d8-a216ef04daea
# 9947  151935af-07f4-44d7-9957-22f5534ec531
# 9967  19cf5229-4f01-4db1-bcfd-8ca66d747028
# 9992  48557629-7b42-4b16-8e44-8f864bd6def2
#
#                                customer_id     customer_name  \
# 1     64739806-004e-4622-b2af-3028f64fd7db     Ricardo Lynch
# 14    3794120b-6015-4245-ab32-867f2d168d88       Julia Lopez
# 49    8c5891cd-7d09-414c-a015-3f8df933eb73        Mark Craig
# 50    0068dc1c-f1a2-4951-91b6-fae817a33cbf     Yvette Walker
# 52    08abc92f-9c16-4e00-afd0-cea29467959a  Samantha Jackson
# ...                                    ...               ...
# 9923  033ca02c-c4c4-4478-b3fb-54fa5fead23a        John Smith
# 9924  28d1d6bf-4af1-4ab8-9e09-a53aed1d8a85     Joshua Norman
# 9947  802658bc-b013-49ce-8440-c78eb5387792      Daniel Jones
# 9967  afb85826-af42-4e2e-9411-7d08112153f9      Nancy Juarez
# 9992  3f2dc3a8-f64c-40d8-979c-6802b8a5f8d8    Jared Mcdonald
#
#                                 product_id product_name product_category  \
# 1     2db443d1-d1ce-487e-820a-8296b90bb529        Novel            Books
# 14    d4ed8988-64ef-4a83-8bd6-9fdc4130c9e4        Chair        Furniture
# 49    a9bbe267-8883-4919-b5e3-a82c22ff0f89        Novel            Books
# 50    dfbafe01-03d1-46bf-9092-3c8f846566f3    Golf Club           Sports
# 52    c932f5c7-eb85-4871-995d-d7d371a91afa        Novel            Books
# ...                                    ...          ...              ...
# 9923  d6be1753-2356-4708-adfa-c08ce783dbe8       Comics            Books
# 9924  073fc1d7-41d7-4ae6-bbe8-ce2516fc5aad      T-shirt         Clothing
# 9947  b48d5d2b-6076-4d05-aef6-109c53f4180c     Cookbook            Books
# 9967  1c814b71-9bc6-46c9-bc90-5cb463a0834b   Smartphone      Electronics
# 9992  3fe5e305-a7b2-4b42-be0f-ace44f31609e    Biography            Books
#
#           payment_type   qty   price             datetime  country  \
# 1              Unknown     1  204.86  2020-08-26 14:21:38  Unknown
# 14                card  1000  453.37  2024-08-10 16:42:42  Unknown
# 49             Unknown     6  154.28  2023-07-06 15:35:43  Unknown
# 50              Wallet  1000  416.93  2020-02-25 03:25:45  Unknown
# 52             Unknown     1  487.50  2023-05-09 05:41:54  Unknown
# ...                ...   ...     ...                  ...      ...
# 9923              card     0  299.45  2023-02-28 22:19:30  Unknown
# 9924  Internet Banking     2 -100.00  2020-12-16 18:51:35  Unknown
# 9947              card     5    0.00  2022-03-25 17:43:29  Unknown
# 9967               UPI     0  108.25  2023-12-14 22:58:18  Unknown
# 9992              card     0  178.37  2022-12-17 17:57:52  Unknown
#
#                    city ecommerce_website_name  \
# 1         Johnstonshire                 Myntra
# 14             Boydland                 Myntra
# 49          Xaviershire                 Myntra
# 50         Sanchezburgh                 Amazon
# 52        East Ianmouth                 Myntra
# ...                 ...                    ...
# 9923           New Jane                 Meesho
# 9924  East Gabrielabury                   eBay
# 9947         Jorgehaven                 Meesho
# 9967        Allisonfort                   eBay
# 9992   New Christinaton               Flipkart
#
#                             payment_txn_id payment_txn_success  \
# 1     ef033396-47a1-4d0e-b889-52ee6481da05                   Y
# 14    83c956fe-3b47-4007-bf25-779ec9efb5f1                   Y
# 49    f82263d9-22a7-4539-8cc8-8361ea021ae3                   Y
# 50    9aa6cdf8-acfe-4386-85c9-39f5486faeec                   Y
# 52    09b5cf1f-56cf-46fc-9703-347fe90aab92                   N
# ...                                    ...                 ...
# 9923  f24a3f30-3705-4fe1-8b45-f7853440937d                   Y
# 9924  80654902-7518-42b0-8f83-520c82f89cec                   N
# 9947  b3fb31a9-c624-4297-aeba-0d88dc907f44                   N
# 9967  5964634b-ea62-4760-8a09-d67ab83a2725                   Y
# 9992  537fdd30-3cb8-4a2b-85bb-4b0e88c963b1                   N
#
#                                        failure_reason
# 1                                                 NaN
# 14                                                NaN
# 49                                                NaN
# 50                                                NaN
# 52                            Month nation both cell.
# ...                                               ...
# 9923                                              NaN
# 9924  Put could seat beautiful protect test standard.
# 9947                    Price apply very skill trial.
# 9967                                              NaN
# 9992             Same assume feel past those medical.
#
# [855 rows x 16 columns]

# %%
df[df['country'] == 'Unknown'].shape[0]
# Out:
# 855

# %% [markdown]
# Checking for Duplicate Records

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Data cleaning

# %% [markdown]
# Handle Invalid Quantities

# %%
#Replace invalid quantities with a median or a valid default value
median_qty = df['qty'].median()
df['qty'] = df['qty'].apply(lambda x: median_qty if x <= 0 or x > 100 else x)

# %%
df['qty']
# Out:
# 0       9.0
# 1       1.0
# 2       9.0
# 3       9.0
# 4       5.0
#        ...
# 9995    6.0
# 9996    6.0
# 9997    8.0
# 9998    6.0
# 9999    3.0
# Name: qty, Length: 10000, dtype: float64

# %% [markdown]
# Handle Invalid Prices

# %%
#Replace invalid prices with the median or a valid default value
median_price = df['price'].median()
df['price'] = df['price'].apply(lambda x: median_price if x <= 0 else x)

# %%
df['price']
# Out:
# 0       319.01
# 1       204.86
# 2        30.41
# 3       173.50
# 4       406.38
#          ...
# 9995    140.14
# 9996    227.37
# 9997    392.29
# 9998    447.28
# 9999    391.21
# Name: price, Length: 10000, dtype: float64

# %% [markdown]
# Handle Invalid Payment Types

# %%
#Replace invalid payment types with the mode (most common value)
mode_payment_type = df['payment_type'].mode()[0]
df['payment_type'] = df['payment_type'].replace('Unknown', mode_payment_type)

# %%
df['payment_type']
# Out:
# 0                   card
# 1                    UPI
# 2                 Wallet
# 3       Internet Banking
# 4                 Wallet
#               ...
# 9995                 UPI
# 9996                card
# 9997                 UPI
# 9998                 UPI
# 9999                card
# Name: payment_type, Length: 10000, dtype: object

# %% [markdown]
# Handle Invalid Country Names

# %%
#Replace invalid country names with the mode (most common value)
mode_country = df['country'].mode()[0]
df['country'] = df['country'].replace('Unknown', mode_country)

# %%
df[df['country'] == 'Unknown'].shape[0]
# Out:
# 0

# %% [markdown]
# Handling Missing Values

# %%
# Fill missing values 
df['failure_reason'] = df['failure_reason'].fillna('No Failure')

# %%
df.to_csv('cleaned_data.csv', index=False)

# %% [markdown]
# Data Analysis

# %% [markdown]
# 1. Top-Selling Category of Items (Overall and Per Country)

# %%
#Overall Top-Selling Category
top_category_overall = df.groupby('product_category')['qty'].sum().sort_values(ascending=False).reset_index()
print("Overall Top-Selling Category:")
print(top_category_overall.head(1))
# Out:
# Overall Top-Selling Category:
#   product_category     qty
# 0            Books  8666.0

# %%
#op-Selling Category Per Country
top_category_per_country = df.groupby(['country', 'product_category'])['qty'].sum().reset_index()
top_category_per_country = top_category_per_country.sort_values(['country', 'qty'], ascending=[True, False]).drop_duplicates('country')
print("Top-Selling Category Per Country:")
print(top_category_per_country)
# Out:
# Top-Selling Category Per Country:
#           country product_category     qty
# 0       Australia            Books  1437.0
# 8          Brazil      Electronics  1325.0
# 12         Canada            Books  1363.0
# 21        Germany        Furniture  2148.0
# 29          India           Sports  1358.0
# 30  United States            Books  1413.0

# %% [markdown]
# 2. Popularity of Products Throughout the Year (Overall and Per Country)

# %%
#Overall Product Popularity Throughout the Year:
df['month'] = pd.to_datetime(df['datetime']).dt.month
product_popularity_overall = df.groupby(['month', 'product_category'])['qty'].sum().unstack().fillna(0)
print("Product Popularity Throughout the Year (Overall):")
print(product_popularity_overall)
# Out:
# Product Popularity Throughout the Year (Overall):
# product_category  Books  Clothing  Electronics  Furniture  Grocery  Sports
# month
# 1                 710.0     819.0        809.0      658.0    862.0   776.0
# 2                 786.0     705.0        643.0      659.0    768.0   638.0
# 3                 715.0     658.0        843.0      715.0    731.0   707.0
# 4                 762.0     722.0        761.0      728.0    808.0   775.0
# 5                 688.0     779.0        775.0      723.0    822.0   700.0
# 6                 784.0     738.0        608.0      717.0    783.0   684.0
# 7                 888.0     852.0        786.0      730.0    702.0   797.0
# 8                 724.0     744.0        794.0      723.0    690.0   667.0
# 9                 583.0     621.0        608.0      617.0    609.0   584.0
# 10                690.0     681.0        602.0      465.0    520.0   682.0
# 11                637.0     561.0        533.0      516.0    641.0   557.0
# 12                699.0     556.0        563.0      598.0    503.0   664.0

# %%
#Product Popularity Per Country
product_popularity_per_country = df.groupby(['country', 'month', 'product_category'])['qty'].sum().unstack().fillna(0)
print("Product Popularity Per Country:")
print(product_popularity_per_country)
# Out:
# Product Popularity Per Country:
# product_category     Books  Clothing  Electronics  Furniture  Grocery  Sports
# country       month
# Australia     1       98.0     127.0        104.0       89.0    116.0   121.0
#               2       99.0      99.0        120.0      104.0    128.0   113.0
#               3      114.0     110.0        166.0      118.0    156.0    94.0
#               4      142.0      94.0        135.0       85.0    141.0   123.0
#               5       91.0     142.0        142.0      120.0    124.0    85.0
# ...                    ...       ...          ...        ...      ...     ...
# United States 8      154.0     130.0        102.0       72.0    112.0   111.0
#               9      110.0     138.0         92.0       91.0     91.0    60.0
#               10     117.0     121.0         69.0       77.0     42.0    86.0
#               11      92.0      83.0        113.0       93.0    120.0    66.0
#               12      85.0      46.0         81.0       56.0     99.0   102.0
#
# [72 rows x 6 columns]

# %% [markdown]
# 3. Locations with the Highest Traffic of Sales

# %%
#Highest Traffic Locations:
highest_traffic_locations = df.groupby(['country', 'city'])['qty'].sum().sort_values(ascending=False).reset_index()
print("Locations with Highest Traffic of Sales:")
print(highest_traffic_locations.head(10))
# Out:
# Locations with Highest Traffic of Sales:
#          country              city   qty
# 0         Canada    North Jennifer  31.0
# 1         Brazil       Michaelfurt  28.0
# 2        Germany      West William  26.0
# 3  United States     South William  25.0
# 4  United States  East Christopher  24.0
# 5         Canada         New David  23.0
# 6      Australia       Williamfurt  23.0
# 7      Australia       South James  22.0
# 8        Germany        East Julie  21.0
# 9        Germany      West Michael  21.0

# %% [markdown]
# 4. Times with the Highest Traffic of Sales (Overall and Per Country)

# %%
#Overall Peak Sales Times:
df['hour'] = pd.to_datetime(df['datetime']).dt.hour
peak_times_overall = df.groupby('hour')['qty'].sum().sort_values(ascending=False).reset_index()
print("Overall Peak Sales Times:")
print(peak_times_overall.head(10))
# Out:
# Overall Peak Sales Times:
#    hour     qty
# 0     4  2262.0
# 1     6  2258.0
# 2    22  2243.0
# 3    20  2242.0
# 4    14  2219.0
# 5     9  2188.0
# 6    19  2147.0
# 7     2  2139.0
# 8     1  2135.0
# 9    23  2112.0

# %%
#Peak Sales Times Per Country:
peak_times_per_country = df.groupby(['country', 'hour'])['qty'].sum().reset_index()
peak_times_per_country = peak_times_per_country.sort_values(['country', 'qty'], ascending=[True, False]).drop_duplicates('country')
print("Peak Sales Times Per Country:")
print(peak_times_per_country)
# Out:
# Peak Sales Times Per Country:
#            country  hour    qty
# 1        Australia     1  410.0
# 40          Brazil    16  355.0
# 54          Canada     6  360.0
# 86         Germany    14  622.0
# 102          India     6  440.0
# 122  United States     2  397.0

# %% [markdown]
# visualization

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (3.9.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pillow>=8 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: six>=1.5 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the 'C:\Users\P.BHARGAV\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# 1. Top-Selling Category of Items (Overall and Per Country)

# %%
#a. Overall Top-Selling Category (Bar Chart)
import matplotlib.pyplot as plt

top_category_overall.plot(kind='bar', x='product_category', y='qty', legend=False)
plt.title('Top-Selling Categories Overall')
plt.xlabel('Product Category')
plt.ylabel('Total Quantity Sold')
plt.xticks(rotation=45)
plt.show()

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.0.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\p.bhargav\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the 'C:\Users\P.BHARGAV\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
#b. Top-Selling Category Per Country (Bar Chart)
import seaborn as sns

plt.figure(figsize=(14, 7))
sns.barplot(x='country', y='qty', hue='product_category', data=top_category_per_country)
plt.title('Top-Selling Categories Per Country')
plt.xlabel('Country')
plt.ylabel('Total Quantity Sold')
plt.xticks(rotation=45)
plt.legend(title='Product Category')
plt.show()

# %% [markdown]
# 2. Popularity of Products Throughout the Year (Overall and Per Country)

# %%
#Line Chart for Overall Product Popularity Throughout the Year
product_popularity_overall.plot(kind='line', figsize=(14, 7))
plt.title('Product Popularity Throughout the Year (Overall)')
plt.xlabel('Month')
plt.ylabel('Quantity Sold')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend(title='Product Category')
plt.show()

# %%
#Line Chart for Product Popularity Per Country
for country in df['country'].unique():
    df_country = df[df['country'] == country]
    product_popularity = df_country.groupby(['month', 'product_category'])['qty'].sum().unstack().fillna(0)
    
    product_popularity.plot(kind='line', figsize=(14, 7))
    plt.title(f'Product Popularity Throughout the Year in {country}')
    plt.xlabel('Month')
    plt.ylabel('Quantity Sold')
    plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
    plt.legend(title='Product Category')
    plt.show()

# %% [markdown]
# 3. Locations with the Highest Traffic of Sales

# %%
#Bar Chart for Locations with the Highest Traffic of Sales:
top_locations = highest_traffic_locations.head(10)
plt.figure(figsize=(14, 7))
sns.barplot(x='city', y='qty', hue='country', data=top_locations)
plt.title('Top 10 Locations with Highest Traffic of Sales')
plt.xlabel('City')
plt.ylabel('Total Quantity Sold')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 4. Times with the Highest Traffic of Sales (Overall and Per Country)

# %%
#Line Chart for Overall Peak Sales Times:
peak_times_overall.plot(kind='line', x='hour', y='qty', figsize=(14, 7))
plt.title('Overall Peak Sales Times')
plt.xlabel('Hour of the Day')
plt.ylabel('Quantity Sold')
plt.xticks(ticks=range(0, 24), labels=[f'{i}:00' for i in range(24)])
plt.grid(True)
plt.show()

# %%
#Line Chart for Peak Sales Times Per Country
for country in df['country'].unique():
    df_country = df[df['country'] == country]
    peak_times = df_country.groupby('hour')['qty'].sum().reset_index()
    
    peak_times.plot(kind='line', x='hour', y='qty', figsize=(14, 7))
    plt.title(f'Peak Sales Times in {country}')
    plt.xlabel('Hour of the Day')
    plt.ylabel('Quantity Sold')
    plt.xticks(ticks=range(0, 24), labels=[f'{i}:00' for i in range(24)])
    plt.grid(True)
    plt.show()
